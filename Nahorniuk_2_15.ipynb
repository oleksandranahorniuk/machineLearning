# %% [markdown]
# 1. Виведіть перші 5 рядків таблиці.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

url = "https://uk.wikipedia.org/wiki/%D0%A1%D0%B5%D1%80%D0%B5%D0%B4%D0%BD%D1%8F_%D0%B7%D0%B0%D1%80%D0%BE%D0%B1%D1%96%D1%82%D0%BD%D0%B0_%D0%BF%D0%BB%D0%B0%D1%82%D0%B0_%D0%B2_%D0%A3%D0%BA%D1%80%D0%B0%D1%97%D0%BD%D1%96"
data = pd.read_html(url, header=0)[2]

#Task1: Виведіть перші 5 рядків таблиці.

df_1 = data.head(5)
print(df_1)
data
# Out:
#     Рік В національній валюті В доларах США  \
# 0  1992              5832,88▲        28,04▼
# 1  1993               163533▲        36,03▲
# 2  1994              1426343▲        44,99▲
# 3  1995              7304000▲        49,53▲
# 4  1996               125,23▼        68,45▲
#
#   Кількість кг хліба[20] на середню зарплату  \
# 0                                   1015,67▲
# 1                                    430,42▼
# 2                                    372,76▼
# 3                                    201,76▼
# 4                                    198,62▼
#
#   Кількість БігМаків на середню зарплату
# 0                                      —
# 1                                      —
# 2                                      —
# 3                                      —
# 4                                      —
#       Рік В національній валюті В доларах США  \
# 0    1992              5832,88▲        28,04▼
# 1    1993               163533▲        36,03▲
# ...

# %% [markdown]
# 2. Визначте кількість рядків і стовпчиків за допомогою атрибуту shape

# %%
columns, lines = df_1.shape
print(columns, lines)
data
# Out:
# 5 5
#       Рік В національній валюті В доларах США  \
# 0    1992              5832,88▲        28,04▼
# 1    1993               163533▲        36,03▲
# 2    1994              1426343▲        44,99▲
# 3    1995              7304000▲        49,53▲
# 4    1996               125,23▼        68,45▲
# 5    1997               143,09▲        76,86▲
# 6    1998               152,83▲        62,39▼
# 7    1999               177,39▲        42,95▼
# 8    2000               231,04▲        42,47▼
# 9    2001               311,62▲        58,01▲
# 10   2002               375,98▲        70,59▲
# 11   2003               462,58▲        86,74▲
# 12   2004               590,53▲       111,02▲
# 13   2005               806,14▲       157,30▲
# 14   2006              1042,88▲       206,51▲
# 15   2007              1352,75▲       267,87▲
# 16   2008              1808,92▲       343,43▲
# 17   2009              1909,25▲       245,05▼
# 18   2010              2246,75▲       283,12▲
# ...

# %% [markdown]
# 3. Визначте загальну кількість років та кількість місяців у даних.

# %%
num_years = len(df_1['Рік']) - 1
num_months = num_years*12

print("Загальна кількість років: ", num_years)
print("Загальна кількість місяців: ", num_months)
# Out:
# Загальна кількість років:  4
# Загальна кількість місяців:  48

# %% [markdown]
# 4. Замінити пропущені значення  «-» в таблиці на NaN

# %%
data_clean = data.replace(to_replace = "—", value = np.NaN)
data_clean
# Out:
#       Рік В національній валюті В доларах США  \
# 0    1992              5832,88▲        28,04▼
# 1    1993               163533▲        36,03▲
# 2    1994              1426343▲        44,99▲
# 3    1995              7304000▲        49,53▲
# 4    1996               125,23▼        68,45▲
# 5    1997               143,09▲        76,86▲
# 6    1998               152,83▲        62,39▼
# 7    1999               177,39▲        42,95▼
# 8    2000               231,04▲        42,47▼
# 9    2001               311,62▲        58,01▲
# 10   2002               375,98▲        70,59▲
# 11   2003               462,58▲        86,74▲
# 12   2004               590,53▲       111,02▲
# 13   2005               806,14▲       157,30▲
# 14   2006              1042,88▲       206,51▲
# 15   2007              1352,75▲       267,87▲
# 16   2008              1808,92▲       343,43▲
# 17   2009              1909,25▲       245,05▼
# 18   2010              2246,75▲       283,12▲
# ...

# %% [markdown]
# 5. Визначити тип стовпців за допомогою dtypes

# %%
columns_types = data.dtypes
print(columns_types)
# Out:
# Рік                                           object
# В національній валюті                         object
# В доларах США                                 object
# Кількість кг хліба[20] на середню зарплату    object
# Кількість БігМаків на середню зарплату        object
# dtype: object

# %% [markdown]
# 6. Видаліть передостанній і останній стовпчики ( Кількість кгхліба[20] на середнюзарплату,  Кільксть БігМаків на середню зарплату). Далі працюйте з оновленою таблицею.

# %%
new_data = data_clean.drop(["Кількість кг хліба[20] на середню зарплату"], axis = 1)
new_data1 = new_data.drop(["Кількість БігМаків на середню зарплату"], axis = 1)
print(new_data1)
# Out:
#       Рік В національній валюті В доларах США
# 0    1992              5832,88▲        28,04▼
# 1    1993               163533▲        36,03▲
# 2    1994              1426343▲        44,99▲
# 3    1995              7304000▲        49,53▲
# 4    1996               125,23▼        68,45▲
# 5    1997               143,09▲        76,86▲
# 6    1998               152,83▲        62,39▼
# 7    1999               177,39▲        42,95▼
# 8    2000               231,04▲        42,47▼
# 9    2001               311,62▲        58,01▲
# 10   2002               375,98▲        70,59▲
# 11   2003               462,58▲        86,74▲
# 12   2004               590,53▲       111,02▲
# 13   2005               806,14▲       157,30▲
# 14   2006              1042,88▲       206,51▲
# 15   2007              1352,75▲       267,87▲
# 16   2008              1808,92▲       343,43▲
# 17   2009              1909,25▲       245,05▼
# 18   2010              2246,75▲       283,12▲
# ...

# %%
for col in new_data1.columns[1:]:
    new_data1[col] = new_data1[col].str.replace(',', '.').str.extract('(\d+.\d+)').astype(float)
print(new_data1.dtypes)
print(new_data1)
# Out:
# Рік                       object
# В національній валюті    float64
# В доларах США            float64
# dtype: object
#       Рік  В національній валюті  В доларах США
# 0    1992                5832.88          28.04
# 1    1993              163533.00          36.03
# 2    1994             1426343.00          44.99
# 3    1995             7304000.00          49.53
# 4    1996                 125.23          68.45
# 5    1997                 143.09          76.86
# 6    1998                 152.83          62.39
# 7    1999                 177.39          42.95
# 8    2000                 231.04          42.47
# 9    2001                 311.62          58.01
# 10   2002                 375.98          70.59
# 11   2003                 462.58          86.74
# 12   2004                 590.53         111.02
# 13   2005                 806.14         157.30
# 14   2006                1042.88         206.51
# 15   2007                1352.75         267.87
# ...

# %% [markdown]
# 8. Порахуйте частку пропусків в кожній колонці (за допомогою методів isnull , sum, len)

# %%
part = new_data1.isnull().sum()/len(df_1)
print(part)
# Out:
# Рік                      0.0
# В національній валюті    0.0
# В доларах США            0.0
# dtype: float64

# %% [markdown]
# 9. Замініть всі пропущені значення на середні значення по (стовпцю).

# %%
new_data1 = new_data1.fillna(new_data1.mean())
new_data1
# Out:
# <ipython-input-112-ac3f8bd12001>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   new_data1 = new_data1.fillna(new_data1.mean())
#       Рік  В національній валюті  В доларах США
# 0    1992                5832.88          28.04
# 1    1993              163533.00          36.03
# 2    1994             1426343.00          44.99
# 3    1995             7304000.00          49.53
# 4    1996                 125.23          68.45
# 5    1997                 143.09          76.86
# 6    1998                 152.83          62.39
# 7    1999                 177.39          42.95
# 8    2000                 231.04          42.47
# 9    2001                 311.62          58.01
# 10   2002                 375.98          70.59
# ...

# %% [markdown]
# 10. Знайдіть рік з найвищою зарплатою в Україні в грн і вкажіть цю зарплату.

# %%
max_value = new_data1['В національній валюті'].max()
max_row = new_data1.loc[new_data1['В національній валюті'].idxmax()]['Рік']
print(f"The biggest salary: {max_value}")
print(f"Year: {max_row}")
# Out:
# The biggest salary: 7304000.0
# Year: 1995

# %% [markdown]
# 11. Знайдіть рік з мінімальною  зарплатою в Україні в дол. США і вкажіть цю зарплату.

# %%
min_value = new_data1['В національній валюті'].min()
min_row = new_data1.loc[new_data1['В національній валюті'].idxmin()]['Рік']
print(f"The lowest salary: {min_value}")
print(f"Year: {min_row}")
# Out:
# The lowest salary: 125.23
# Year: 1996

# %% [markdown]
# 12. Виведіть роки, коли зарплата в грн була вище середньої.

# %%
avg_salary = new_data1['В національній валюті'].mean()
above_average_years = new_data1[new_data1['В національній валюті'] > avg_salary]['Рік']

# %% [markdown]
# 13. Порівняйте  зарплату  в грн за останні два доступних роки.

# %%
value1 = new_data1.at[30, 'В національній валюті']
value2 = new_data1.at[31, 'В національній валюті']

if value2 > value1:
        result = f"Зарплата в 2022 році ({value2} грн) вища за зарплату в 2021 році ({value1} грн)."
elif value2 < value1:
    result = f"Зарплата в 2022 році ({value2} грн) нижча за зарплату в 2021 році ({value1} грн)."
else:
    result = f"Зарплата в 2022 році ({value2} грн) дорівнює зарплаті в 2021 році ({value1} грн)."

print(result)
# Out:
# Зарплата в 2022 році (12954.12 грн) нижча за зарплату в 2021 році (13376.21 грн).

# %% [markdown]
# 14. Створіть графік, що відображає  зарплату в Україні з часом (за роками).

# %%
years = new_data1['Рік']
salaries_UAH = new_data1['В національній валюті']

plt.figure(figsize=(10, 5))
plt.plot(years, salaries_UAH, marker='o', linestyle='-', color='g')
plt.title('Динаміка зарплати в Україні')
plt.xlabel('Рік')
plt.ylabel('Зарплата в грн')
plt.grid(True)
plt.show()

# %% [markdown]
# 15. Видаліть останній рік з таблиці та виведіть оновлену таблицю.

# %%
new_data1 = new_data1.drop(new_data1.index[-1])

new_data1
# Out:
#       Рік  В національній валюті  В доларах США
# 0    1992                5832.88          28.04
# 1    1993              163533.00          36.03
# 2    1994             1426343.00          44.99
# 3    1995             7304000.00          49.53
# 4    1996                 125.23          68.45
# 5    1997                 143.09          76.86
# 6    1998                 152.83          62.39
# 7    1999                 177.39          42.95
# 8    2000                 231.04          42.47
# 9    2001                 311.62          58.01
# 10   2002                 375.98          70.59
# 11   2003                 462.58          86.74
# 12   2004                 590.53         111.02
# 13   2005                 806.14         157.30
# 14   2006                1042.88         206.51
# 15   2007                1352.75         267.87
# 16   2008                1808.92         343.43
# 17   2009                1909.25         245.05
# 18   2010                2246.75         283.12
# ...

# %% [markdown]
# 16. Побудуйте графік, що відображає середню зарплату в Україні в розрізі років без останнього року.

# %%
years = new_data1['Рік'][:-1]
salaries = new_data1['В національній валюті'][:-1]


plt.figure(figsize=(20, 6))
plt.plot(years, salaries, marker='o', color='g')
plt.title('Середня зарплата в Україні за роки (без останнього)')
plt.xlabel('Рік')
plt.ylabel('Середня зарплата (грн)')
plt.grid(True)

plt.show()

# %% [markdown]
# 17. Обчисліть зарплату за останні два роки і порівняйте її із зарплатою за останні 5 років. Вкажіть, чи є різниця, і в якому напрямку.

# %%
last_five_years = new_data1.tail(5)

last_two_years = new_data1.tail(2)

salary_for_5 = last_five_years['В національній валюті'].sum()

salary_for_2 = last_two_years['В національній валюті'].sum()

if salary_for_2 > salary_for_5:
    result = "Зарплата за останні два роки вища за зарплату за останні 5 років."
elif salary_for_2 < salary_for_5:
    result = "Зарплата за останні два роки нижча за зарплату за останні 5 років."
else:
    result = "Зарплата за останні два роки дорівнює зарплаті за останні 5 років."

print(result)

#Зарплата за останні два роки нижча за зарплату за останні 5 років.
# Out:
# Зарплата за останні два роки нижча за зарплату за останні 5 років.

# %% [markdown]
# Висновок: На практичній роботі я навчилась працювати з бібліотекою pandas, numpy, а саме: скачувати таблиці, видаляти та додавати рядки, змінювати та порівнювати дані, змінювати тип даних та виводити дані в графіках.
